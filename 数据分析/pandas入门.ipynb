# %%
import pandas as pd

# 构造DateFrame -- 创建数据集（学员成绩信息）
df = pd.DataFrame([
    {"姓名": "小王", "语文": 90, "数学": 70, "英语": 86},
    {"姓名": "小李", "语文": 80, "数学": 76, "英语": 67},
    {"姓名": "小刘", "语文": 96, "数学": 75, "英语": 67},
    {"姓名": "小赵", "语文": 66, "数学": 67, "英语": 87},
    {"姓名": "小孙", "语文": 76, "数学": 98, "英语": 98},
    {"姓名": "小玉", "语文": 98, "数学": 67, "英语": 67},
    {"姓名": "小新", "语文": 56, "数学": 87, "英语": 98},
])

# 统计计算
print(f"语文最高分：{df["语文"].max()}，最低分：{df["语文"].min():2f}，平均分：{df["语文"].mean()}")
print(f"数学最高分：{df["数学"].max()}，最低分：{df["数学"].min():2f}，平均分：{df["数学"].mean()}")
print(f"英语最高分：{df["英语"].max()}，最低分：{df["英语"].min():2f}，平均分：{df["英语"].mean()}")
# Out:
# 语文最高分：98，最低分：56.000000，平均分：80.28571428571429
# 数学最高分：98，最低分：67.000000，平均分：77.14285714285714
# 英语最高分：98，最低分：67.000000，平均分：81.42857142857143
